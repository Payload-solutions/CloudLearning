# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data_regression_set.csv")

# %%
data
# Out:
#       streptococcus_initial_strain_cfu_ml  \
# 0                                   4.693
# 1                                   4.786
# 2                                   5.342
# 3                                   5.733
# 4                                   5.106
# ...                                   ...
# 1054                                5.474
# 1055                                4.489
# 1056                                5.399
# 1057                                4.106
# 1058                                5.494
#
#       lactobacillus_initial_strain_cfu_ml  ideal_temperature_c  \
# 0                                   5.376               40.593
# 1                                   5.447               41.374
# 2                                   5.963               41.399
# 3                                   4.516               40.782
# 4                                   4.097               40.159
# ...                                   ...                  ...
# ...

# %%
data.columns
# Out:
# Index(['streptococcus_initial_strain_cfu_ml',
#        'lactobacillus_initial_strain_cfu_ml', 'ideal_temperature_c',
#        'minimum_milk_proteins', 'titratable_acidity', 'pH_milk_sour_',
#        'fat_milk_over_100mg_', 'quality_product', 'lactobacillus_final_cfu_ml',
#        'streptococcus_final_cfu_ml'],
#       dtype='object')

# %%
print(data["streptococcus_initial_strain_cfu_ml"].max())
# Out:
# 5.998

# %%
for x in data["streptococcus_initial_strain_cfu_ml"].to_list():
    if x >= 5.997:
        print(x)
# Out:
# 5.998
# 5.997
# 5.997

# %%
for x in data.columns:
    
    print("{} max value => {} min value => {}".format(x, data[x].max(), data[x].min()))
# Out:
# streptococcus_initial_strain_cfu_ml max value => 5.998 min value => 4.004
# lactobacillus_initial_strain_cfu_ml max value => 5.998 min value => 4.001
# ideal_temperature_c max value => 41.995 min value => 40.001
# minimum_milk_proteins max value => 2.7 min value => 2.4
# titratable_acidity max value => 1.19 min value => 0.95
# pH_milk_sour_ max value => 4.6 min value => 4.4
# fat_milk_over_100mg_ max value => 3.9993 min value => 1.003
# quality_product max value => Regular yogurt min value => Low fat yogurt
# lactobacillus_final_cfu_ml max value => 10.06 min value => 6.71
# streptococcus_final_cfu_ml max value => 10.06 min value => 6.72
